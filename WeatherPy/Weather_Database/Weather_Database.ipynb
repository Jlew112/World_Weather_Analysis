# %%
#import random module and numpy
import random
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests
from config import weather_api_key
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print("City not found. Skipping...")
        #print(e)
        #print(weather_description)
        #break

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | bowen
# Processing Record 3 of Set 1 | kakching
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | tuatapere
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | walvis bay
# Processing Record 13 of Set 1 | sehithwa
# Processing Record 14 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 1 | yokadouma
# Processing Record 16 of Set 1 | makakilo city
# Processing Record 17 of Set 1 | xam nua
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | yulara
# Processing Record 22 of Set 1 | nishihara
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | ambon
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | hamilton
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | kyshtovka
# Processing Record 35 of Set 1 | barroquinha
# Processing Record 36 of Set 1 | nazare
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | sorland
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | agadez
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | tuy hoa
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | nome
# Processing Record 46 of Set 1 | eggenfelden
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | richards bay
# Processing Record 50 of Set 1 | san cristobal
# Processing Record 1 of Set 2 | tilichiki
# Processing Record 2 of Set 2 | aklavik
# Processing Record 3 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 2 | olga
# Processing Record 5 of Set 2 | hualmay
# Processing Record 6 of Set 2 | ordynskoye
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 8 of Set 2 | haines junction
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | fonte boa
# Processing Record 11 of Set 2 | novyy urengoy
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | burley
# Processing Record 14 of Set 2 | vestmannaeyjar
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | lydenburg
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | roebourne
# Processing Record 19 of Set 2 | ottawa
# Processing Record 20 of Set 2 | labuhan
# Processing Record 21 of Set 2 | coihaique
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | machico
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | sirajganj
# Processing Record 34 of Set 2 | vila franca do campo
# Processing Record 35 of Set 2 | maningrida
# Processing Record 36 of Set 2 | tarakan
# Processing Record 37 of Set 2 | kurmanayevka
# Processing Record 38 of Set 2 | lagos
# Processing Record 39 of Set 2 | kahului
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | awbari
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | los alamos
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | coahuayana
# Processing Record 46 of Set 2 | port elizabeth
# Processing Record 47 of Set 2 | praia da vitoria
# Processing Record 48 of Set 2 | vila velha
# Processing Record 49 of Set 2 | saint-pierre
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | comodoro rivadavia
# Processing Record 2 of Set 3 | hushitai
# Processing Record 3 of Set 3 | starodzhereliyevskaya
# Processing Record 4 of Set 3 | sakaiminato
# Processing Record 5 of Set 3 | doha
# Processing Record 6 of Set 3 | burica
# City not found. Skipping...
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | cravo norte
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | ligatne
# Processing Record 12 of Set 3 | yar-sale
# Processing Record 13 of Set 3 | ouallam
# Processing Record 14 of Set 3 | coshocton
# Processing Record 15 of Set 3 | raudeberg
# Processing Record 16 of Set 3 | hobart
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | krizevci
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | clyde river
# Processing Record 24 of Set 3 | abu zabad
# Processing Record 25 of Set 3 | north platte
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | opuwo
# Processing Record 29 of Set 3 | sorrento
# Processing Record 30 of Set 3 | margate
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | malanje
# Processing Record 33 of Set 3 | souillac
# Processing Record 34 of Set 3 | necochea
# Processing Record 35 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 3 | san policarpo
# Processing Record 37 of Set 3 | tommot
# Processing Record 38 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 39 of Set 3 | saint-joseph
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | coolum beach
# Processing Record 42 of Set 3 | conde
# Processing Record 43 of Set 3 | san ramon
# Processing Record 44 of Set 3 | taltal
# Processing Record 45 of Set 3 | tromso
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | hermanus
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | zyryanka
# Processing Record 1 of Set 4 | teguise
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | vyazma
# Processing Record 4 of Set 4 | tonj
# Processing Record 5 of Set 4 | mount gambier
# Processing Record 6 of Set 4 | okhotsk
# Processing Record 7 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 4 | pundaguitan
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | baturaja
# Processing Record 11 of Set 4 | nichinan
# Processing Record 12 of Set 4 | ambilobe
# Processing Record 13 of Set 4 | anadyr
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | batagay-alyta
# Processing Record 16 of Set 4 | bengbu
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | emba
# Processing Record 19 of Set 4 | maceio
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | oussouye
# Processing Record 22 of Set 4 | tasiilaq
# Processing Record 23 of Set 4 | ayr
# Processing Record 24 of Set 4 | talnakh
# Processing Record 25 of Set 4 | quatre cocos
# Processing Record 26 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 4 | alugan
# Processing Record 29 of Set 4 | sinnamary
# Processing Record 30 of Set 4 | dashitou
# Processing Record 31 of Set 4 | kilindoni
# Processing Record 32 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 4 | saint-philippe
# Processing Record 34 of Set 4 | pangnirtung
# Processing Record 35 of Set 4 | buritizeiro
# Processing Record 36 of Set 4 | coos bay
# Processing Record 37 of Set 4 | mecca
# Processing Record 38 of Set 4 | steinbach
# Processing Record 39 of Set 4 | tadine
# Processing Record 40 of Set 4 | mantua
# Processing Record 41 of Set 4 | san vicente
# Processing Record 42 of Set 4 | pandan
# Processing Record 43 of Set 4 | molokovo
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | egvekinot
# Processing Record 46 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 4 | sussex
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 50 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 5 | kenai
# Processing Record 2 of Set 5 | gat
# Processing Record 3 of Set 5 | jieshi
# Processing Record 4 of Set 5 | boyolangu
# Processing Record 5 of Set 5 | susanville
# Processing Record 6 of Set 5 | vostok
# Processing Record 7 of Set 5 | port pirie
# Processing Record 8 of Set 5 | rawson
# Processing Record 9 of Set 5 | tevaitoa
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | atar
# Processing Record 12 of Set 5 | sorong
# Processing Record 13 of Set 5 | rio gallegos
# Processing Record 14 of Set 5 | pisco
# Processing Record 15 of Set 5 | bria
# Processing Record 16 of Set 5 | asau
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | kings mountain
# Processing Record 19 of Set 5 | kodiak
# Processing Record 20 of Set 5 | atasu
# Processing Record 21 of Set 5 | namatanai
# Processing Record 22 of Set 5 | grindavik
# Processing Record 23 of Set 5 | khani
# Processing Record 24 of Set 5 | presidente franco
# Processing Record 25 of Set 5 | faya
# Processing Record 26 of Set 5 | pekalongan
# Processing Record 27 of Set 5 | sabancuy
# Processing Record 28 of Set 5 | namibe
# Processing Record 29 of Set 5 | farafenni
# Processing Record 30 of Set 5 | cap malheureux
# Processing Record 31 of Set 5 | ola
# Processing Record 32 of Set 5 | petropavlovskoye
# Processing Record 33 of Set 5 | miri
# Processing Record 34 of Set 5 | kralendijk
# Processing Record 35 of Set 5 | nouadhibou
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | garowe
# Processing Record 40 of Set 5 | brookhaven
# Processing Record 41 of Set 5 | atikokan
# Processing Record 42 of Set 5 | marystown
# Processing Record 43 of Set 5 | regina
# Processing Record 44 of Set 5 | bambous virieux
# Processing Record 45 of Set 5 | smidovich
# Processing Record 46 of Set 5 | tsumeb
# Processing Record 47 of Set 5 | severo-kurilsk
# Processing Record 48 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 5 | lebu
# Processing Record 50 of Set 5 | lasa
# Processing Record 1 of Set 6 | thilogne
# City not found. Skipping...
# Processing Record 2 of Set 6 | taoudenni
# Processing Record 3 of Set 6 | da nang
# Processing Record 4 of Set 6 | sanary-sur-mer
# Processing Record 5 of Set 6 | vung tau
# Processing Record 6 of Set 6 | joensuu
# Processing Record 7 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | aljezur
# Processing Record 10 of Set 6 | sulangan
# Processing Record 11 of Set 6 | itarema
# Processing Record 12 of Set 6 | port lincoln
# Processing Record 13 of Set 6 | kudahuvadhoo
# Processing Record 14 of Set 6 | tayoltita
# Processing Record 15 of Set 6 | vao
# Processing Record 16 of Set 6 | veracruz
# Processing Record 17 of Set 6 | chapais
# Processing Record 18 of Set 6 | sao joao da barra
# Processing Record 19 of Set 6 | arraial do cabo
# Processing Record 20 of Set 6 | sindor
# Processing Record 21 of Set 6 | argelia
# Processing Record 22 of Set 6 | paamiut
# Processing Record 23 of Set 6 | matara
# Processing Record 24 of Set 6 | solonytsivka
# Processing Record 25 of Set 6 | santa maria
# Processing Record 26 of Set 6 | matane
# Processing Record 27 of Set 6 | port blair
# Processing Record 28 of Set 6 | charleston
# Processing Record 29 of Set 6 | eureka
# Processing Record 30 of Set 6 | witrivier
# City not found. Skipping...
# Processing Record 31 of Set 6 | teguldet
# Processing Record 32 of Set 6 | longyearbyen
# Processing Record 33 of Set 6 | uige
# Processing Record 34 of Set 6 | broome
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | almaznyy
# Processing Record 37 of Set 6 | cedral
# Processing Record 38 of Set 6 | umm kaddadah
# Processing Record 39 of Set 6 | ancud
# Processing Record 40 of Set 6 | adrar
# Processing Record 41 of Set 6 | rock hill
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | mount isa
# Processing Record 44 of Set 6 | moussoro
# Processing Record 45 of Set 6 | pimenta bueno
# Processing Record 46 of Set 6 | central point
# Processing Record 47 of Set 6 | roblin
# Processing Record 48 of Set 6 | champerico
# Processing Record 49 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 50 of Set 6 | barrhead
# Processing Record 1 of Set 7 | victor harbor
# Processing Record 2 of Set 7 | khandyga
# Processing Record 3 of Set 7 | tigzirt
# Processing Record 4 of Set 7 | forestville
# Processing Record 5 of Set 7 | tigil
# Processing Record 6 of Set 7 | iqaluit
# Processing Record 7 of Set 7 | san carlos de bariloche
# Processing Record 8 of Set 7 | borogontsy
# Processing Record 9 of Set 7 | ardesen
# Processing Record 10 of Set 7 | pringsewu
# Processing Record 11 of Set 7 | kinsale
# Processing Record 12 of Set 7 | lichinga
# Processing Record 13 of Set 7 | vermilion
# Processing Record 14 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 16 of Set 7 | balaka
# Processing Record 17 of Set 7 | zhigansk
# Processing Record 18 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 19 of Set 7 | komsomolskiy
# Processing Record 20 of Set 7 | ust-nera
# Processing Record 21 of Set 7 | nakhon phanom
# Processing Record 22 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 7 | chukhloma
# Processing Record 24 of Set 7 | zhangye
# Processing Record 25 of Set 7 | verkhnyaya inta
# Processing Record 26 of Set 7 | juneau
# Processing Record 27 of Set 7 | soyaux
# Processing Record 28 of Set 7 | port victoria
# Processing Record 29 of Set 7 | durazno
# Processing Record 30 of Set 7 | menongue
# Processing Record 31 of Set 7 | poum
# Processing Record 32 of Set 7 | benguela
# Processing Record 33 of Set 7 | nadym
# Processing Record 34 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 7 | dong hoi
# Processing Record 36 of Set 7 | astakos
# Processing Record 37 of Set 7 | walla walla
# Processing Record 38 of Set 7 | pilar
# Processing Record 39 of Set 7 | saint-leu
# Processing Record 40 of Set 7 | ingleside
# Processing Record 41 of Set 7 | hsinchu
# Processing Record 42 of Set 7 | yei
# Processing Record 43 of Set 7 | lompoc
# Processing Record 44 of Set 7 | zhongxing
# Processing Record 45 of Set 7 | laguna
# Processing Record 46 of Set 7 | saint anthony
# Processing Record 47 of Set 7 | broken hill
# Processing Record 48 of Set 7 | katsuura
# Processing Record 49 of Set 7 | russellville
# Processing Record 50 of Set 7 | manokwari
# Processing Record 1 of Set 8 | ocampo
# Processing Record 2 of Set 8 | sungay
# City not found. Skipping...
# Processing Record 3 of Set 8 | anakapalle
# Processing Record 4 of Set 8 | kisaran
# Processing Record 5 of Set 8 | geraldton
# Processing Record 6 of Set 8 | avigliano
# Processing Record 7 of Set 8 | nanortalik
# Processing Record 8 of Set 8 | saint-augustin
# Processing Record 9 of Set 8 | calabozo
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | beauchamps
# Processing Record 12 of Set 8 | hohhot
# Processing Record 13 of Set 8 | cabedelo
# Processing Record 14 of Set 8 | panalingaan
# Processing Record 15 of Set 8 | melfort
# Processing Record 16 of Set 8 | san quintin
# Processing Record 17 of Set 8 | kawalu
# Processing Record 18 of Set 8 | kavaratti
# Processing Record 19 of Set 8 | zhezkazgan
# Processing Record 20 of Set 8 | miles city
# Processing Record 21 of Set 8 | adamovka
# Processing Record 22 of Set 8 | airai
# Processing Record 23 of Set 8 | mayo
# Processing Record 24 of Set 8 | tinskoy
# Processing Record 25 of Set 8 | buchanan
# Processing Record 26 of Set 8 | seoul
# Processing Record 27 of Set 8 | kumbhraj
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | sri aman
# Processing Record 30 of Set 8 | hanting
# Processing Record 31 of Set 8 | kisangani
# Processing Record 32 of Set 8 | didwana
# Processing Record 33 of Set 8 | kotido
# Processing Record 34 of Set 8 | ketchikan
# Processing Record 35 of Set 8 | yerofey pavlovich
# Processing Record 36 of Set 8 | daru
# Processing Record 37 of Set 8 | yuli
# Processing Record 38 of Set 8 | teresopolis
# Processing Record 39 of Set 8 | gravdal
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | sur
# Processing Record 42 of Set 8 | camalu
# Processing Record 43 of Set 8 | gushikawa
# Processing Record 44 of Set 8 | garsten
# Processing Record 45 of Set 8 | callosa de segura
# Processing Record 46 of Set 8 | lakes entrance
# Processing Record 47 of Set 8 | severodvinsk
# Processing Record 48 of Set 8 | syriam
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 8 | martinho campos
# Processing Record 1 of Set 9 | pangody
# Processing Record 2 of Set 9 | ulaangom
# Processing Record 3 of Set 9 | uruacu
# Processing Record 4 of Set 9 | dukat
# Processing Record 5 of Set 9 | caruray
# Processing Record 6 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 9 | codrington
# Processing Record 8 of Set 9 | evensk
# Processing Record 9 of Set 9 | ibipeba
# Processing Record 10 of Set 9 | mango
# Processing Record 11 of Set 9 | zhuhai
# Processing Record 12 of Set 9 | ahipara
# Processing Record 13 of Set 9 | floro
# Processing Record 14 of Set 9 | acapulco
# Processing Record 15 of Set 9 | rorvik
# Processing Record 16 of Set 9 | meulaboh
# Processing Record 17 of Set 9 | puerto ayacucho
# Processing Record 18 of Set 9 | valadares
# Processing Record 19 of Set 9 | waipawa
# Processing Record 20 of Set 9 | boa vista
# Processing Record 21 of Set 9 | katobu
# Processing Record 22 of Set 9 | esik
# Processing Record 23 of Set 9 | husavik
# Processing Record 24 of Set 9 | samana
# Processing Record 25 of Set 9 | altagracia de orituco
# Processing Record 26 of Set 9 | kulevcha
# Processing Record 27 of Set 9 | mvuma
# Processing Record 28 of Set 9 | neiafu
# Processing Record 29 of Set 9 | salalah
# Processing Record 30 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 9 | luena
# Processing Record 32 of Set 9 | lavrentiya
# Processing Record 33 of Set 9 | tura
# Processing Record 34 of Set 9 | novichikha
# Processing Record 35 of Set 9 | genhe
# Processing Record 36 of Set 9 | hoi an
# Processing Record 37 of Set 9 | uvira
# Processing Record 38 of Set 9 | bobo dioulasso
# Processing Record 39 of Set 9 | oistins
# Processing Record 40 of Set 9 | klaksvik
# Processing Record 41 of Set 9 | naro-fominsk
# Processing Record 42 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 9 | itapirapua
# Processing Record 44 of Set 9 | tazmalt
# Processing Record 45 of Set 9 | synya
# Processing Record 46 of Set 9 | honiara
# Processing Record 47 of Set 9 | sile
# Processing Record 48 of Set 9 | arteaga
# Processing Record 49 of Set 9 | aswan
# Processing Record 50 of Set 9 | nemuro
# Processing Record 1 of Set 10 | tiarei
# Processing Record 2 of Set 10 | demyansk
# Processing Record 3 of Set 10 | marsh harbour
# Processing Record 4 of Set 10 | zhicheng
# Processing Record 5 of Set 10 | clarence town
# Processing Record 6 of Set 10 | ahuimanu
# Processing Record 7 of Set 10 | kalomo
# City not found. Skipping...
# Processing Record 8 of Set 10 | shenjiamen
# Processing Record 9 of Set 10 | zhanakorgan
# Processing Record 10 of Set 10 | akcakoca
# Processing Record 11 of Set 10 | jiangyou
# Processing Record 12 of Set 10 | selma
# Processing Record 13 of Set 10 | jardin
# Processing Record 14 of Set 10 | hami
# Processing Record 15 of Set 10 | palmer
# Processing Record 16 of Set 10 | ronne
# Processing Record 17 of Set 10 | qasigiannguit
# Processing Record 18 of Set 10 | helong
# Processing Record 19 of Set 10 | kyzyl-suu
# Processing Record 20 of Set 10 | bac lieu
# Processing Record 21 of Set 10 | palana
# Processing Record 22 of Set 10 | lamu
# Processing Record 23 of Set 10 | kruisfontein
# Processing Record 24 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 10 | giyani
# Processing Record 26 of Set 10 | luderitz
# Processing Record 27 of Set 10 | moree
# Processing Record 28 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 10 | college
# Processing Record 30 of Set 10 | bathsheba
# Processing Record 31 of Set 10 | port hedland
# Processing Record 32 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 10 | yining
# Processing Record 34 of Set 10 | halifax
# Processing Record 35 of Set 10 | constantine
# Processing Record 36 of Set 10 | te anau
# Processing Record 37 of Set 10 | port shepstone
# Processing Record 38 of Set 10 | aykhal
# Processing Record 39 of Set 10 | shache
# Processing Record 40 of Set 10 | pahrump
# Processing Record 41 of Set 10 | provideniya
# Processing Record 42 of Set 10 | port augusta
# Processing Record 43 of Set 10 | rimavska sobota
# Processing Record 44 of Set 10 | poya
# Processing Record 45 of Set 10 | wachtberg
# Processing Record 46 of Set 10 | vanimo
# Processing Record 47 of Set 10 | flinders
# Processing Record 48 of Set 10 | moskovskiy
# Processing Record 49 of Set 10 | swan river
# Processing Record 50 of Set 10 | kirensk
# Processing Record 1 of Set 11 | conceicao do araguaia
# Processing Record 2 of Set 11 | inhambane
# Processing Record 3 of Set 11 | senanga
# Processing Record 4 of Set 11 | bhikhi
# Processing Record 5 of Set 11 | olden
# Processing Record 6 of Set 11 | ossora
# Processing Record 7 of Set 11 | mackay
# Processing Record 8 of Set 11 | rurrenabaque
# Processing Record 9 of Set 11 | murray
# Processing Record 10 of Set 11 | jingdezhen
# Processing Record 11 of Set 11 | calamar
# Processing Record 12 of Set 11 | yumen
# Processing Record 13 of Set 11 | pathein
# Processing Record 14 of Set 11 | nagato
# Processing Record 15 of Set 11 | bonnyville
# Processing Record 16 of Set 11 | mount pleasant
# Processing Record 17 of Set 11 | tukrah
# Processing Record 18 of Set 11 | maragogi
# Processing Record 19 of Set 11 | ponta delgada
# Processing Record 20 of Set 11 | szczytno
# Processing Record 21 of Set 11 | spas-klepiki
# Processing Record 22 of Set 11 | potiskum
# Processing Record 23 of Set 11 | port hardy
# Processing Record 24 of Set 11 | sao joaquim
# Processing Record 25 of Set 11 | tayga
# Processing Record 26 of Set 11 | reconquista
# Processing Record 27 of Set 11 | nedjo
# Processing Record 28 of Set 11 | knokke-heist
# Processing Record 29 of Set 11 | terme
# Processing Record 30 of Set 11 | ayan
# Processing Record 31 of Set 11 | illapel
# Processing Record 32 of Set 11 | moose factory
# Processing Record 33 of Set 11 | inongo
# Processing Record 34 of Set 11 | pochutla
# Processing Record 35 of Set 11 | rantepao
# Processing Record 36 of Set 11 | whyalla
# Processing Record 37 of Set 11 | tabriz
# Processing Record 38 of Set 11 | tambul
# City not found. Skipping...
# Processing Record 39 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 40 of Set 11 | kalyazin
# Processing Record 41 of Set 11 | hobyo
# Processing Record 42 of Set 11 | grand gaube
# Processing Record 43 of Set 11 | samarai
# Processing Record 44 of Set 11 | port antonio
# Processing Record 45 of Set 11 | havre
# Processing Record 46 of Set 11 | deputatskiy
# Processing Record 47 of Set 11 | mailsi
# Processing Record 48 of Set 11 | matadi
# Processing Record 49 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 11 | pacific grove
# Processing Record 1 of Set 12 | raymond terrace
# Processing Record 2 of Set 12 | brae
# Processing Record 3 of Set 12 | muli
# Processing Record 4 of Set 12 | luga
# Processing Record 5 of Set 12 | tynda
# Processing Record 6 of Set 12 | plettenberg bay
# Processing Record 7 of Set 12 | avera
# Processing Record 8 of Set 12 | parkes
# Processing Record 9 of Set 12 | lata
# Processing Record 10 of Set 12 | mabaruma
# Processing Record 11 of Set 12 | namanga
# Processing Record 12 of Set 12 | guozhen
# Processing Record 13 of Set 12 | smithers
# Processing Record 14 of Set 12 | phangnga
# Processing Record 15 of Set 12 | santa isabel do rio negro
# Processing Record 16 of Set 12 | hambantota
# Processing Record 17 of Set 12 | chiplun
# Processing Record 18 of Set 12 | russell
# Processing Record 19 of Set 12 | wright
# Processing Record 20 of Set 12 | whitehorse
# Processing Record 21 of Set 12 | komsomolsk
# Processing Record 22 of Set 12 | inzai
# Processing Record 23 of Set 12 | uthai thani
# Processing Record 24 of Set 12 | babu
# Processing Record 25 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 12 | milton
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | chirongui
# Processing Record 29 of Set 12 | port-gentil
# Processing Record 30 of Set 12 | okato
# Processing Record 31 of Set 12 | caravelas
# Processing Record 32 of Set 12 | angoche
# Processing Record 33 of Set 12 | marrakesh
# Processing Record 34 of Set 12 | coquimbo
# Processing Record 35 of Set 12 | karakose
# City not found. Skipping...
# Processing Record 36 of Set 12 | sheltozero
# Processing Record 37 of Set 12 | ponta do sol
# Processing Record 38 of Set 12 | suntar
# Processing Record 39 of Set 12 | arua
# Processing Record 40 of Set 12 | elbrus
# Processing Record 41 of Set 12 | skjervoy
# Processing Record 42 of Set 12 | choachi
# Processing Record 43 of Set 12 | eyl
# Processing Record 44 of Set 12 | holme
# Processing Record 45 of Set 12 | huanren
# Processing Record 46 of Set 12 | clearwater
# Processing Record 47 of Set 12 | khangarh
# Processing Record 48 of Set 12 | nsunga
# Processing Record 49 of Set 12 | olafsvik
# Processing Record 50 of Set 12 | harper
# Processing Record 1 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 2 of Set 13 | voykove
# Processing Record 3 of Set 13 | jinxiang
# Processing Record 4 of Set 13 | emerald
# Processing Record 5 of Set 13 | shar
# Processing Record 6 of Set 13 | lieksa
# Processing Record 7 of Set 13 | sao filipe
# Processing Record 8 of Set 13 | fairbanks
# Processing Record 9 of Set 13 | fort saint james
# Processing Record 10 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 13 | filingue
# Processing Record 12 of Set 13 | sobolevo
# Processing Record 13 of Set 13 | kadoma
# Processing Record 14 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 15 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 16 of Set 13 | blythe
# Processing Record 17 of Set 13 | flin flon
# Processing Record 18 of Set 13 | benghazi
# Processing Record 19 of Set 13 | pulandian
# Processing Record 20 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 21 of Set 13 | huarmey
# Processing Record 22 of Set 13 | la grande
# Processing Record 23 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 24 of Set 13 | hendijan
# City not found. Skipping...
# Processing Record 25 of Set 13 | tirumala
# Processing Record 26 of Set 13 | goroka
# Processing Record 27 of Set 13 | stornoway
# Processing Record 28 of Set 13 | palencia
# Processing Record 29 of Set 13 | khudumelapye
# Processing Record 30 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 31 of Set 13 | takaka
# Processing Record 32 of Set 13 | vallenar
# Processing Record 33 of Set 13 | kangaatsiaq
# Processing Record 34 of Set 13 | kimbe
# Processing Record 35 of Set 13 | vila
# Processing Record 36 of Set 13 | primore
# City not found. Skipping...
# Processing Record 37 of Set 13 | arivonimamo
# Processing Record 38 of Set 13 | rzhaksa
# Processing Record 39 of Set 13 | viedma
# Processing Record 40 of Set 13 | kalmunai
# Processing Record 41 of Set 13 | srednekolymsk
# Processing Record 42 of Set 13 | arman
# Processing Record 43 of Set 13 | hunterville
# Processing Record 44 of Set 13 | botad
# Processing Record 45 of Set 13 | talcahuano
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | kerman
# Processing Record 48 of Set 13 | sidrolandia
# Processing Record 49 of Set 13 | solnechnyy
# Processing Record 50 of Set 13 | naze
# Processing Record 1 of Set 14 | ulaanbaatar
# Processing Record 2 of Set 14 | puerto colombia
# Processing Record 3 of Set 14 | umm lajj
# Processing Record 4 of Set 14 | umarkot
# Processing Record 5 of Set 14 | rafsanjan
# Processing Record 6 of Set 14 | trincomalee
# Processing Record 7 of Set 14 | banjarmasin
# Processing Record 8 of Set 14 | malpe
# Processing Record 9 of Set 14 | bubaque
# Processing Record 10 of Set 14 | olinda
# Processing Record 11 of Set 14 | fort nelson
# Processing Record 12 of Set 14 | chepo
# Processing Record 13 of Set 14 | calama
# Processing Record 14 of Set 14 | villafranca de los barros
# Processing Record 15 of Set 14 | killybegs
# Processing Record 16 of Set 14 | iberia
# Processing Record 17 of Set 14 | gharghoda
# Processing Record 18 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 19 of Set 14 | beira
# Processing Record 20 of Set 14 | shaowu
# Processing Record 21 of Set 14 | wanning
# Processing Record 22 of Set 14 | prince rupert
# Processing Record 23 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 14 | knysna
# Processing Record 26 of Set 14 | kirakira
# Processing Record 27 of Set 14 | mbandaka
# Processing Record 28 of Set 14 | pitimbu
# Processing Record 29 of Set 14 | carauari
# Processing Record 30 of Set 14 | gull lake
# Processing Record 31 of Set 14 | hare bay
# Processing Record 32 of Set 14 | sainte-marie
# Processing Record 33 of Set 14 | tongren
# Processing Record 34 of Set 14 | mindelo
# Processing Record 35 of Set 14 | winslow
# Processing Record 36 of Set 14 | carmelo
# Processing Record 37 of Set 14 | santa vitoria do palmar
# Processing Record 38 of Set 14 | griffith
# Processing Record 39 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 14 | ayagoz
# Processing Record 41 of Set 14 | tarko-sale
# Processing Record 42 of Set 14 | cayenne
# Processing Record 43 of Set 14 | maniwaki
# Processing Record 44 of Set 14 | touros
# Processing Record 45 of Set 14 | tufesti
# Processing Record 46 of Set 14 | puerto leguizamo
# Processing Record 47 of Set 14 | presidente medici
# Processing Record 48 of Set 14 | mana
# Processing Record 49 of Set 14 | half moon bay
# Processing Record 50 of Set 14 | beruwala
# Processing Record 1 of Set 15 | youkounkoun
# Processing Record 2 of Set 15 | saldanha
# Processing Record 3 of Set 15 | sao felix do xingu
# Processing Record 4 of Set 15 | dodge city
# Processing Record 5 of Set 15 | bodden town
# Processing Record 6 of Set 15 | zhangjiakou
# Processing Record 7 of Set 15 | bonthe
# Processing Record 8 of Set 15 | panaba
# Processing Record 9 of Set 15 | urfa
# City not found. Skipping...
# Processing Record 10 of Set 15 | ixtapa
# Processing Record 11 of Set 15 | constitucion
# Processing Record 12 of Set 15 | konevo
# Processing Record 13 of Set 15 | nuuk
# Processing Record 14 of Set 15 | ojinaga
# Processing Record 15 of Set 15 | santa cruz
# Processing Record 16 of Set 15 | san juan
# Processing Record 17 of Set 15 | mokrous
# Processing Record 18 of Set 15 | galle
# Processing Record 19 of Set 15 | westport
# Processing Record 20 of Set 15 | navolato
# Processing Record 21 of Set 15 | carutapera
# Processing Record 22 of Set 15 | kenora
# Processing Record 23 of Set 15 | general higinio morinigo
# Processing Record 24 of Set 15 | batemans bay
# Processing Record 25 of Set 15 | severomuysk
# Processing Record 26 of Set 15 | kamakwie
# Processing Record 27 of Set 15 | morolica
# City not found. Skipping...
# Processing Record 28 of Set 15 | humaita
# Processing Record 29 of Set 15 | joetsu
# Processing Record 30 of Set 15 | abashiri
# Processing Record 31 of Set 15 | tapes
# Processing Record 32 of Set 15 | saint-francois
# Processing Record 33 of Set 15 | singaraja
# Processing Record 34 of Set 15 | mercedes
# Processing Record 35 of Set 15 | moravske budejovice
# Processing Record 36 of Set 15 | macau
# Processing Record 37 of Set 15 | lao cai
# Processing Record 38 of Set 15 | khorramshahr
# Processing Record 39 of Set 15 | goba
# Processing Record 40 of Set 15 | vardo
# Processing Record 41 of Set 15 | ilhabela
# Processing Record 42 of Set 15 | cotonou
# Processing Record 43 of Set 15 | alta
# Processing Record 44 of Set 15 | port macquarie
# Processing Record 45 of Set 15 | isla mujeres
# Processing Record 46 of Set 15 | niono
# Processing Record 47 of Set 15 | gazojak
# Processing Record 48 of Set 15 | rudbar
# Processing Record 49 of Set 15 | tabou
# Processing Record 50 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 16 | takoradi
# Processing Record 2 of Set 16 | mooi river
# City not found. Skipping...
# Processing Record 3 of Set 16 | kastamonu
# Processing Record 4 of Set 16 | bjala
# City not found. Skipping...
# Processing Record 5 of Set 16 | kilkenny
# Processing Record 6 of Set 16 | riyadh
# Processing Record 7 of Set 16 | oskemen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga      RU  71.9667  102.5000     45.52        60          13
# 1         Bowen      AU -20.0167  148.2333     69.28        73          89
# 2      Kakching      IN  24.4833   93.9833     69.98        89          54
# 3  Punta Arenas      CL -53.1500  -70.9167     48.31        37           0
# 4         Vaini      TO -21.2000 -175.2000     71.76        94          90
# 5       Mataura      NZ -46.1927  168.8643     46.47        94         100
# 6         Sitka      US  57.0531 -135.3300     55.29        88          90
# 7     Carnarvon      AU -24.8667  113.6333     62.67        67           0
# 8     Tuatapere      NZ -46.1333  167.6833     46.81        85         100
# 9     Cape Town      ZA -33.9258   18.4232     62.89        76          89
#
#    Wind Speed Current Description
# 0       12.28          few clouds
# 1       10.07     overcast clouds
# 2        2.55       broken clouds
# 3       14.97           clear sky
# 4        6.91     overcast clouds
# 5        4.88     overcast clouds
# 6       10.36                mist
# 7       17.27           clear sky
# 8       10.27       moderate rain
# 9        1.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
